# %% [markdown]
# # Prepare

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/user/Documents/github/donkatsu/')
sys.path.append('/Users/user/Documents/github/lii3ra/')
from donkatsu.dbinfo import DbInfo
import psycopg2
conn = psycopg2.connect(
    host=DbInfo.HOSTNAME,
    database=DbInfo.DATABASE,
    port=DbInfo.PORT,
    user=DbInfo.USER_NAME,
    password=DbInfo.PASSWORD
)
cur = conn.cursor()
import matplotlib.pyplot as plt
from mpl_finance import candlestick2_ohlc, volume_overlay, candlestick_ohlc
import seaborn as sns
sns.set()
sns.set_style('whitegrid')
sns.set_palette('gray')

# %%
# %load_ext sql
dsl = f"postgres://{DbInfo.USER_NAME}:{DbInfo.PASSWORD}@{DbInfo.HOSTNAME}:{DbInfo.PORT}/{DbInfo.DATABASE}"
# %sql $dsl
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: postgres@donkatsu'

# %% [markdown]
# # 銘柄精査
#  - [x] 出来高1億円以上 2019年の平均

# %%
# %%sql
# select
#  symbol
# ,avg(volume * close)
# from ohlcv
# where symbol like '%.T'
# and date(time) between '2019-01-01' and '2019-12-31'
# and volume != 'nan'
# and close != 'nan'
# group by symbol
# having avg(volume * close) > 100000000
# order by 1
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 1184 rows affected.
# [('1321.T', 5515586348.00926),
#  ('1332.T', 1513310856.84647),
#  ('1333.T', 681198928.215768),
#  ('1356.T', 430673512.009132),
#  ('1357.T', 25027005679.9289),
#  ('1377.T', 335790286.307054),
#  ('1379.T', 128445630.705394),
#  ('1414.T', 544265024.896266),
#  ('1417.T', 528125472.614108),
#  ('1419.T', 682374982.394366),
#  ('1429.T', 144492903.73444),
#  ('1435.T', 390162215.767635),
#  ('1448.T', 186279640.248963),
#  ('1514.T', 121819817.842324),
#  ('1568.T', 1203634980.82192),
#  ('1570.T', 100517763802.343),
#  ('1571.T', 623952410.421296),
#  ('1605.T', 4955117619.75308),
#  ('1662.T', 543793403.333333),
#  ('1719.T', 592535890.041494),
#  ('1720.T', 320288206.224066),
#  ('1721.T', 1547161929.04564),
#  ('1766.T', 272334734.439834),
#  ('1801.T', 3777145369.29461),
#  ('1802.T', 2404464411.61826),
#  ('1803.T', 2368706188.79668),
#  ('1805.T', 109882558.921162),
#  ('1808.T', 1808508253.52697),
# ...

# %% [markdown]
#  - [x] 出来高3億円以上 2019年の平均

# %%
# %%sql
# select
#  symbol
# --,avg(volume * close)
# from ohlcv
# where symbol like '%.T'
# and date(time) between '2019-01-01' and '2019-12-31'
# and volume != 'nan'
# and close != 'nan'
# group by symbol
# having avg(volume * close) > 300000000
# order by 1
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 768 rows affected.
# [('1321.T',),
#  ('1332.T',),
#  ('1333.T',),
#  ('1356.T',),
#  ('1357.T',),
#  ('1377.T',),
#  ('1414.T',),
#  ('1417.T',),
#  ('1419.T',),
#  ('1435.T',),
#  ('1568.T',),
#  ('1570.T',),
#  ('1571.T',),
#  ('1605.T',),
#  ('1662.T',),
#  ('1719.T',),
#  ('1720.T',),
#  ('1721.T',),
#  ('1801.T',),
#  ('1802.T',),
#  ('1803.T',),
#  ('1808.T',),
#  ('1812.T',),
#  ('1820.T',),
#  ('1821.T',),
#  ('1824.T',),
#  ('1833.T',),
#  ('1860.T',),
#  ('1861.T',),
#  ('1878.T',),
#  ('1881.T',),
#  ('1883.T',),
#  ('1887.T',),
#  ('1893.T',),
#  ('1911.T',),
#  ('1925.T',),
#  ('1926.T',),
#  ('1928.T',),
#  ('1942.T',),
#  ('1944.T',),
#  ('1951.T',),
#  ('1959.T',),
#  ('1963.T',),
#  ('1983.T',),
#  ('2002.T',),
#  ('2120.T',),
#  ('2124.T',),
#  ('2127.T',),
#  ('2130.T',),
#  ('2157.T',),
#  ('2170.T',),
#  ('2175.T',),
#  ('2181.T',),
#  ('2201.T',),
#  ('2206.T',),
#  ('2212.T',),
#  ('2222.T',),
# ...

# %% [markdown]
#  - [x] 出来高5億円以上 2019年の平均

# %%
# %%sql
# select
#  symbol
# ,avg(volume * close)
# from ohlcv
# where symbol like '%.T'
# and date(time) between '2019-01-01' and '2019-12-31'
# and volume != 'nan'
# and close != 'nan'
# group by symbol
# having avg(volume * close) > 500000000
# order by 1
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 585 rows affected.
# [('1321.T', 5515586348.00926),
#  ('1332.T', 1513310856.84647),
#  ('1333.T', 681198928.215768),
#  ('1357.T', 25027005679.9289),
#  ('1414.T', 544265024.896266),
#  ('1417.T', 528125472.614108),
#  ('1419.T', 682374982.394366),
#  ('1568.T', 1203634980.82192),
#  ('1570.T', 100517763802.343),
#  ('1571.T', 623952410.421296),
#  ('1605.T', 4955117619.75308),
#  ('1662.T', 543793403.333333),
#  ('1719.T', 592535890.041494),
#  ('1721.T', 1547161929.04564),
#  ('1801.T', 3777145369.29461),
#  ('1802.T', 2404464411.61826),
#  ('1803.T', 2368706188.79668),
#  ('1808.T', 1808508253.52697),
#  ('1812.T', 2447212295.43568),
#  ('1820.T', 665136053.941909),
#  ('1824.T', 687915273.443983),
#  ('1861.T', 622391273.75),
#  ('1878.T', 4638569363.07054),
#  ('1883.T', 562452772.614108),
#  ('1887.T', 514174998.00995),
#  ('1893.T', 1018959269.29461),
#  ('1911.T', 706972978.423236),
#  ('1925.T', 5867497086.51452),
# ...

# %% [markdown]
#  - [x] 出来高10億円以上 2019年の平均

# %%
# %%sql
# select
#  symbol
# ,avg(volume * close)
# from ohlcv
# where symbol like '%.T'
# and date(time) between '2019-01-01' and '2019-12-31'
# and volume != 'nan'
# and close != 'nan'
# group by symbol
# having avg(volume * close) > 1000000000
# order by 1
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 393 rows affected.
# [('1321.T', 5515586348.00926),
#  ('1332.T', 1513310856.84647),
#  ('1357.T', 25027005679.9289),
#  ('1568.T', 1203634980.82192),
#  ('1570.T', 100517763802.343),
#  ('1605.T', 4955117619.75308),
#  ('1721.T', 1547161929.04564),
#  ('1801.T', 3777145369.29461),
#  ('1802.T', 2404464411.61826),
#  ('1803.T', 2368706188.79668),
#  ('1808.T', 1808508253.52697),
#  ('1812.T', 2447212295.43568),
#  ('1878.T', 4638569363.07054),
#  ('1893.T', 1018959269.29461),
#  ('1925.T', 5867497086.51452),
#  ('1928.T', 4545886335.06224),
#  ('1951.T', 1282193976.76349),
#  ('1963.T', 2693821212.44813),
#  ('2002.T', 1487310308.71369),
#  ('2127.T', 1953786502.90456),
#  ('2181.T', 2389224339.41909),
#  ('2229.T', 1185381521.57676),
#  ('2267.T', 2518504954.35685),
#  ('2269.T', 2866227896.26556),
#  ('2282.T', 1878833628.63071),
#  ('2326.T', 1304263311.20332),
#  ('2371.T', 2197671905.80913),
#  ('2379.T', 1121026185.89212),
# ...

# %% [markdown]
# # TOPIX17ETF

# %% [markdown]
# ## 1617.T 食品

# %%
# %%sql
# select
# symbol
# ,avg(volume * close)
# from ohlcv
# where symbol in (
#         '1301.T'
#         , '1332.T'
#         , '1333.T'
#         , '1376.T'
#         , '1377.T'
#         , '1379.T'
#         , '1384.T'
#         , '2001.T'
#         , '2002.T'
#         , '2003.T'
#         , '2004.T'
#         , '2009.T'
#         , '2053.T'
#         , '2060.T'
#         , '2107.T'
#         , '2108.T'
#         , '2109.T'
#         , '2112.T'
#         , '2117.T'
#         , '2201.T'
#         , '2204.T'
#         , '2206.T'
#         , '2207.T'
#         , '2209.T'
#         , '2211.T'
#         , '2212.T'
#         , '2215.T'
#         , '2217.T'
#         , '2220.T'
#         , '2222.T'
#         , '2229.T'
#         , '2264.T'
#         , '2266.T'
#         , '2267.T'
#         , '2269.T'
#         , '2270.T'
#         , '2281.T'
#         , '2282.T'
#         , '2286.T'
#         , '2288.T'
#         , '2292.T'
#         , '2296.T'
#         , '2501.T'
#         , '2502.T'
#         , '2503.T'
#         , '2531.T'
#         , '2533.T'
#         , '2540.T'
#         , '2579.T'
#         , '2587.T'
#         , '2590.T'
#         , '2593.T'
#         , '2594.T'
#         , '2597.T'
#         , '2599.T'
#         , '2602.T'
#         , '2607.T'
#         , '2612.T'
#         , '2613.T'
#         , '2801.T'
#         , '2802.T'
#         , '2809.T'
#         , '2810.T'
#         , '2811.T'
#         , '2812.T'
#         , '2815.T'
#         , '2818.T'
#         , '2819.T'
#         , '2871.T'
#         , '2875.T'
#         , '2882.T'
#         , '2883.T'
#         , '2884.T'
#         , '2897.T'
#         , '2899.T'
#         , '2904.T'
#         , '2914.T'
#         , '2908.T'
#         , '2910.T'
#         , '2915.T'
#         , '2918.T'
#         , '2922.T'
#         , '2924.T'
#         , '2925.T'
#         , '2930.T'
#         , '2931.T'
#         , '4404.T'
#         , '4526.T'
#         )
# and not close = 'nan'
# and not volume = 'nan'
# group by symbol
# having avg(volume * close) > 1000000000
# order by symbol
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 14 rows affected.
# [('2229.T', 1892497086.85872),
#  ('2267.T', 1572427820.26375),
#  ('2269.T', 4581611383.39746),
#  ('2282.T', 1781866269.40749),
#  ('2502.T', 3932104249.65067),
#  ('2503.T', 4171702995.10058),
#  ('2587.T', 2948446917.44258),
#  ('2593.T', 1384537382.39059),
#  ('2801.T', 1465252451.64907),
#  ('2802.T', 3378239833.68453),
#  ('2875.T', 1212257644.55271),
#  ('2897.T', 1103901520.57623),
#  ('2914.T', 805872778524.339),
#  ('2931.T', 1915420700.97814)]

# %% [markdown]
# # 1618.T エネルギー資源

# %%
# %%sql
# select
# symbol
# ,avg(volume * close)
# from ohlcv
# where symbol in (
#         '1514.T'
#         , '1515.T'
#         , '1518.T'
#         , '1605.T'
#         , '1662.T'
#  ('3863.T', 1316271945.61194),
#  ('4004.T', 2820441545.66043),
#  ('4005.T', 3444515932.39437),
#  ('4021.T', 1574398215.17188),
#  ('4042.T', 1790029490.14085),
#  ('4043.T', 1559868211.37631),
#  ('4061.T', 1044223652.30472),
#  ('4063.T', 9331054999.65724),
#  ('4088.T', 1882771488.11189),
#  ('4182.T', 1819035244.91021),
#  ('4183.T', 2593459107.20454),
#  ('4185.T', 2120154296.11424),
#  ('4188.T', 3306516062.3539),
#  ('4202.T', 1158891087.89584),
#  ('4204.T', 1691534555.87988),
#  ('4205.T', 1144725111.07098),
#  ('4208.T', 1305704336.36364),
#  ('4217.T', 1412869715.80806),
#  ('4452.T', 6825383455.81438),
#  ('4612.T', 1009079524.37211),
#  ('4631.T', 1053858610.04725),
#  ('4901.T', 7521637957.19618),
#  ('4911.T', 4708601758.19996),
# ...

# %% [markdown]
# ## 1621.T 医薬品

# %%
# %%sql
# select
# symbol
# ,avg(volume * close)
# from ohlcv
# where symbol in (
#         '4151.T'
#         , '4502.T'
#         , '4503.T'
#         , '4506.T'
#         , '4507.T'
#         , '4508.T'
#         , '4512.T'
#         , '4514.T'
#         , '4516.T'
#         , '4517.T'
#         , '4519.T'
#         , '4521.T'
#         , '4523.T'
#         , '4527.T'
#         , '4528.T'
#         , '4530.T'
#         , '4534.T'
#         , '4536.T'
#         , '4538.T'
#         , '4539.T'
#         , '4540.T'
#         , '4541.T'
#         , '4547.T'
#         , '4548.T'
#         , '4549.T'
#         , '4550.T'
#         , '4551.T'
#         , '4552.T'
#         , '4553.T'
#         , '4554.T'
#         , '4555.T'
#         , '4559.T'
#         , '4568.T'
#         , '4569.T'
#         , '4574.T'
#         , '4577.T'
#         , '4578.T'
#         , '4581.T'
#         , '4587.T'
#         )
# group by symbol
# order by symbol
# Out:
#  * postgres://postgres:***@localhost:5432/donkatsu
# 39 rows affected.
# [('4151.T', 1486110117.33519),
#  ('4502.T', 14353027594.3637),
#  ('4503.T', 8360894692.68871),
#  ('4506.T', 1475927977.05377),
#  ('4507.T', 3843470250.64708),
#  ('4508.T', 1505954155.29084),
#  ('4512.T', 9370899.62200756),
#  ('4514.T', 70867382.5073498),
#  ('4516.T', 562594940.083998),
#  ('4517.T', 10726829.2649803),
#  ('4519.T', 3186647658.6192),
#  ('4521.T', 649715950.705586),
#  ('4523.T', 5218442033.96734),
#  ('4527.T', 345725990.870035),
#  ('4528.T', 2213519194.83474),
#  ('4530.T', 734575175.629567),
#  ('4534.T', 218715206.446871),
#  ('4536.T', 1708489026.57343),
#  ('4538.T', 25386879.9874003),
#  ('4539.T', 54676499.601008),
#  ('4540.T', 814592834.528139),
#  ('4541.T', 568970989.817776),
#  ('4547.T', 256756435.094498),
#  ('4548.T', 167673109.534221),
#  ('4549.T', 150926011.181973),
#  ('4550.T', 14426131.5872681),
#  ('4551.T', 66943367.2427551),
#  ('4552.T', nan),
# ...

# %% [markdown]
# # ストラテジーによる銘柄選定

# %% [markdown]
#  - [ ] Breakout sigma1 / Newvalue の抽出銘柄のストラテジー確認

# %% [markdown]
#  - [ ] Breakout with a Twist の銘柄抽出

# %% [markdown]
#  - [ ] 出来高10億円以上銘柄のcombination総当り確認
